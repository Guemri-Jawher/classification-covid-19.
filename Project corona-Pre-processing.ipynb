# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Dataset/dataset.csv", index_col=0)
data.head()
# Out:
#                  Patient age quantile SARS-Cov-2 exam result  \
# Patient ID
# 44477f75e8169d2                    13               negative
# 126e9dd13932f68                    17               negative
# a46b4402a0e5696                     8               negative
# f7d619a94f97c45                     5               negative
# d9e41465789c2b5                    15               negative
#
#                  Patient addmited to regular ward (1=yes, 0=no)  \
# Patient ID
# 44477f75e8169d2                                               0
# 126e9dd13932f68                                               0
# a46b4402a0e5696                                               0
# f7d619a94f97c45                                               0
# d9e41465789c2b5                                               0
#
#                  Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# Patient ID
# 44477f75e8169d2                                                  0
# 126e9dd13932f68                                                  0
# a46b4402a0e5696                                                  0
# f7d619a94f97c45                                                  0
# d9e41465789c2b5                                                  0
#
#                  Patient addmited to intensive care unit (1=yes, 0=no)  \
# Patient ID
# 44477f75e8169d2                                                  0
# 126e9dd13932f68                                                  0
# a46b4402a0e5696                                                  0
# f7d619a94f97c45                                                  0
# d9e41465789c2b5                                                  0
#
#                  Hematocrit  Hemoglobin  Platelets  Mean platelet volume   \
# Patient ID
# 44477f75e8169d2         NaN         NaN        NaN                    NaN
# 126e9dd13932f68    0.236515    -0.02234  -0.517413               0.010677
# a46b4402a0e5696         NaN         NaN        NaN                    NaN
# f7d619a94f97c45         NaN         NaN        NaN                    NaN
# d9e41465789c2b5         NaN         NaN        NaN                    NaN
#
#                  Red blood Cells  ...  Hb saturation (arterial blood gases)  \
# Patient ID                        ...
# 44477f75e8169d2              NaN  ...                                   NaN
# 126e9dd13932f68         0.102004  ...                                   NaN
# a46b4402a0e5696              NaN  ...                                   NaN
# f7d619a94f97c45              NaN  ...                                   NaN
# d9e41465789c2b5              NaN  ...                                   NaN
#
#                  pCO2 (arterial blood gas analysis)  \
# Patient ID
# 44477f75e8169d2                                 NaN
# 126e9dd13932f68                                 NaN
# a46b4402a0e5696                                 NaN
# f7d619a94f97c45                                 NaN
# d9e41465789c2b5                                 NaN
#
#                  Base excess (arterial blood gas analysis)  \
# Patient ID
# 44477f75e8169d2                                        NaN
# 126e9dd13932f68                                        NaN
# a46b4402a0e5696                                        NaN
# f7d619a94f97c45                                        NaN
# d9e41465789c2b5                                        NaN
#
#                  pH (arterial blood gas analysis)  \
# Patient ID
# 44477f75e8169d2                               NaN
# 126e9dd13932f68                               NaN
# a46b4402a0e5696                               NaN
# f7d619a94f97c45                               NaN
# d9e41465789c2b5                               NaN
#
#                  Total CO2 (arterial blood gas analysis)  \
# Patient ID
# 44477f75e8169d2                                      NaN
# 126e9dd13932f68                                      NaN
# a46b4402a0e5696                                      NaN
# f7d619a94f97c45                                      NaN
# d9e41465789c2b5                                      NaN
#
#                  HCO3 (arterial blood gas analysis)  \
# Patient ID
# 44477f75e8169d2                                 NaN
# 126e9dd13932f68                                 NaN
# a46b4402a0e5696                                 NaN
# f7d619a94f97c45                                 NaN
# d9e41465789c2b5                                 NaN
#
#                  pO2 (arterial blood gas analysis)  Arteiral Fio2  Phosphor  \
# Patient ID
# 44477f75e8169d2                                NaN            NaN       NaN
# 126e9dd13932f68                                NaN            NaN       NaN
# a46b4402a0e5696                                NaN            NaN       NaN
# f7d619a94f97c45                                NaN            NaN       NaN
# d9e41465789c2b5                                NaN            NaN       NaN
#
#                  ctO2 (arterial blood gas analysis)
# Patient ID
# 44477f75e8169d2                                 NaN
# 126e9dd13932f68                                 NaN
# a46b4402a0e5696                                 NaN
# f7d619a94f97c45                                 NaN
# d9e41465789c2b5                                 NaN
#
# [5 rows x 110 columns]

# %%
df = data.copy()
df.head()
# Out:
#                  Patient age quantile SARS-Cov-2 exam result  \
# Patient ID
# 44477f75e8169d2                    13               negative
# 126e9dd13932f68                    17               negative
# a46b4402a0e5696                     8               negative
# f7d619a94f97c45                     5               negative
# d9e41465789c2b5                    15               negative
#
#                  Patient addmited to regular ward (1=yes, 0=no)  \
# Patient ID
# 44477f75e8169d2                                               0
# 126e9dd13932f68                                               0
# a46b4402a0e5696                                               0
# f7d619a94f97c45                                               0
# d9e41465789c2b5                                               0
#
#                  Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# Patient ID
# 44477f75e8169d2                                                  0
# 126e9dd13932f68                                                  0
# a46b4402a0e5696                                                  0
# f7d619a94f97c45                                                  0
# d9e41465789c2b5                                                  0
#
#                  Patient addmited to intensive care unit (1=yes, 0=no)  \
# Patient ID
# 44477f75e8169d2                                                  0
# 126e9dd13932f68                                                  0
# a46b4402a0e5696                                                  0
# f7d619a94f97c45                                                  0
# d9e41465789c2b5                                                  0
#
#                  Hematocrit  Hemoglobin  Platelets  Mean platelet volume   \
# Patient ID
# 44477f75e8169d2         NaN         NaN        NaN                    NaN
# 126e9dd13932f68    0.236515    -0.02234  -0.517413               0.010677
# a46b4402a0e5696         NaN         NaN        NaN                    NaN
# f7d619a94f97c45         NaN         NaN        NaN                    NaN
# d9e41465789c2b5         NaN         NaN        NaN                    NaN
#
#                  Red blood Cells  ...  Hb saturation (arterial blood gases)  \
# Patient ID                        ...
# 44477f75e8169d2              NaN  ...                                   NaN
# 126e9dd13932f68         0.102004  ...                                   NaN
# a46b4402a0e5696              NaN  ...                                   NaN
# f7d619a94f97c45              NaN  ...                                   NaN
# d9e41465789c2b5              NaN  ...                                   NaN
#
#                  pCO2 (arterial blood gas analysis)  \
# Patient ID
# 44477f75e8169d2                                 NaN
# 126e9dd13932f68                                 NaN
# a46b4402a0e5696                                 NaN
# f7d619a94f97c45                                 NaN
# d9e41465789c2b5                                 NaN
#
#                  Base excess (arterial blood gas analysis)  \
# Patient ID
# 44477f75e8169d2                                        NaN
# 126e9dd13932f68                                        NaN
# a46b4402a0e5696                                        NaN
# f7d619a94f97c45                                        NaN
# d9e41465789c2b5                                        NaN
#
#                  pH (arterial blood gas analysis)  \
# Patient ID
# 44477f75e8169d2                               NaN
# 126e9dd13932f68                               NaN
# a46b4402a0e5696                               NaN
# f7d619a94f97c45                               NaN
# d9e41465789c2b5                               NaN
#
#                  Total CO2 (arterial blood gas analysis)  \
# Patient ID
# 44477f75e8169d2                                      NaN
# 126e9dd13932f68                                      NaN
# a46b4402a0e5696                                      NaN
# f7d619a94f97c45                                      NaN
# d9e41465789c2b5                                      NaN
#
#                  HCO3 (arterial blood gas analysis)  \
# Patient ID
# 44477f75e8169d2                                 NaN
# 126e9dd13932f68                                 NaN
# a46b4402a0e5696                                 NaN
# f7d619a94f97c45                                 NaN
# d9e41465789c2b5                                 NaN
#
#                  pO2 (arterial blood gas analysis)  Arteiral Fio2  Phosphor  \
# Patient ID
# 44477f75e8169d2                                NaN            NaN       NaN
# 126e9dd13932f68                                NaN            NaN       NaN
# a46b4402a0e5696                                NaN            NaN       NaN
# f7d619a94f97c45                                NaN            NaN       NaN
# d9e41465789c2b5                                NaN            NaN       NaN
#
#                  ctO2 (arterial blood gas analysis)
# Patient ID
# 44477f75e8169d2                                 NaN
# 126e9dd13932f68                                 NaN
# a46b4402a0e5696                                 NaN
# f7d619a94f97c45                                 NaN
# d9e41465789c2b5                                 NaN
#
# [5 rows x 110 columns]

# %%
missing_rate = df.isna().sum()/df.shape[0]
missing_rate
# Out:
# Patient age quantile                                     0.000000
# SARS-Cov-2 exam result                                   0.000000
# Patient addmited to regular ward (1=yes, 0=no)           0.000000
# Patient addmited to semi-intensive unit (1=yes, 0=no)    0.000000
# Patient addmited to intensive care unit (1=yes, 0=no)    0.000000
#                                                            ...
# HCO3 (arterial blood gas analysis)                       0.995216
# pO2 (arterial blood gas analysis)                        0.995216
# Arteiral Fio2                                            0.996456
# Phosphor                                                 0.996456
# ctO2 (arterial blood gas analysis)                       0.995216
# Length: 110, dtype: float64

# %%
i=0
for col in df.columns :
    i=i+1
    print (col,i)
# Out:
# Patient age quantile 1
# SARS-Cov-2 exam result 2
# Patient addmited to regular ward (1=yes, 0=no) 3
# Patient addmited to semi-intensive unit (1=yes, 0=no) 4
# Patient addmited to intensive care unit (1=yes, 0=no) 5
# Hematocrit 6
# Hemoglobin 7
# Platelets 8
# Mean platelet volume  9
# Red blood Cells 10
# Lymphocytes 11
# Mean corpuscular hemoglobin concentration (MCHC) 12
# Leukocytes 13
# Basophils 14
# Mean corpuscular hemoglobin (MCH) 15
# Eosinophils 16
# Mean corpuscular volume (MCV) 17
# Monocytes 18
# Red blood cell distribution width (RDW) 19
# Serum Glucose 20
# Respiratory Syncytial Virus 21
# Influenza A 22
# Influenza B 23
# Parainfluenza 1 24
# CoronavirusNL63 25
# Rhinovirus/Enterovirus 26
# Mycoplasma pneumoniae 27
# Coronavirus HKU1 28
# Parainfluenza 3 29
# Chlamydophila pneumoniae 30
# Adenovirus 31
# Parainfluenza 4 32
# Coronavirus229E 33
# CoronavirusOC43 34
# Inf A H1N1 2009 35
# Bordetella pertussis 36
# Metapneumovirus 37
# Parainfluenza 2 38
# Neutrophils 39
# Urea 40
# Proteina C reativa mg/dL 41
# Creatinine 42
# Potassium 43
# Sodium 44
# Influenza B, rapid test 45
# Influenza A, rapid test 46
# Alanine transaminase 47
# Aspartate transaminase 48
# Gamma-glutamyltransferase  49
# Total Bilirubin 50
# Direct Bilirubin 51
# Indirect Bilirubin 52
# Alkaline phosphatase 53
# Ionized calcium  54
# Strepto A 55
# Magnesium 56
# pCO2 (venous blood gas analysis) 57
# Hb saturation (venous blood gas analysis) 58
# Base excess (venous blood gas analysis) 59
# pO2 (venous blood gas analysis) 60
# Fio2 (venous blood gas analysis) 61
# Total CO2 (venous blood gas analysis) 62
# pH (venous blood gas analysis) 63
# HCO3 (venous blood gas analysis) 64
# Rods # 65
# Segmented 66
# Promyelocytes 67
# Metamyelocytes 68
# Myelocytes 69
# Myeloblasts 70
# Urine - Esterase 71
# Urine - Aspect 72
# Urine - pH 73
# Urine - Hemoglobin 74
# Urine - Bile pigments 75
# Urine - Ketone Bodies 76
# Urine - Nitrite 77
# Urine - Density 78
# Urine - Urobilinogen 79
# Urine - Protein 80
# Urine - Sugar 81
# Urine - Leukocytes 82
# Urine - Crystals 83
# Urine - Red blood cells 84
# Urine - Hyaline cylinders 85
# Urine - Granular cylinders 86
# Urine - Yeasts 87
# Urine - Color 88
# Partial thromboplastin time (PTT)  89
# Relationship (Patient/Normal) 90
# International normalized ratio (INR) 91
# Lactic Dehydrogenase 92
# Prothrombin time (PT), Activity 93
# Vitamin B12 94
# Creatine phosphokinase (CPK)  95
# Ferritin 96
# Arterial Lactic Acid 97
# Lipase dosage 98
# D-Dimer 99
# Albumin 100
# Hb saturation (arterial blood gases) 101
# pCO2 (arterial blood gas analysis) 102
# Base excess (arterial blood gas analysis) 103
# pH (arterial blood gas analysis) 104
# Total CO2 (arterial blood gas analysis) 105
# HCO3 (arterial blood gas analysis) 106
# pO2 (arterial blood gas analysis) 107
# Arteiral Fio2 108
# Phosphor 109
# ctO2 (arterial blood gas analysis) 110

# %%
blood_columns = list(df.columns[(missing_rate < 0.9) & (missing_rate >0.88)])
viral_columns = list(df.columns[(missing_rate < 0.80) & (missing_rate > 0.75)])

# %%
key_columns = ['Patient age quantile', 'SARS-Cov-2 exam result']

# %%
df = df[key_columns + blood_columns + viral_columns]
df.head()
# Out:
#                  Patient age quantile SARS-Cov-2 exam result  Hematocrit  \
# Patient ID
# 44477f75e8169d2                    13               negative         NaN
# 126e9dd13932f68                    17               negative    0.236515
# a46b4402a0e5696                     8               negative         NaN
# f7d619a94f97c45                     5               negative         NaN
# d9e41465789c2b5                    15               negative         NaN
#
#                  Hemoglobin  Platelets  Mean platelet volume   \
# Patient ID
# 44477f75e8169d2         NaN        NaN                    NaN
# 126e9dd13932f68    -0.02234  -0.517413               0.010677
# a46b4402a0e5696         NaN        NaN                    NaN
# f7d619a94f97c45         NaN        NaN                    NaN
# d9e41465789c2b5         NaN        NaN                    NaN
#
#                  Red blood Cells  Lymphocytes  \
# Patient ID
# 44477f75e8169d2              NaN          NaN
# 126e9dd13932f68         0.102004     0.318366
# a46b4402a0e5696              NaN          NaN
# f7d619a94f97c45              NaN          NaN
# d9e41465789c2b5              NaN          NaN
#
#                  Mean corpuscular hemoglobin concentration (MCHC)  Leukocytes  \
# Patient ID
# 44477f75e8169d2                                               NaN         NaN
# 126e9dd13932f68                                          -0.95079    -0.09461
# a46b4402a0e5696                                               NaN         NaN
# f7d619a94f97c45                                               NaN         NaN
# d9e41465789c2b5                                               NaN         NaN
#
#                  ...  Parainfluenza 3  Chlamydophila pneumoniae    Adenovirus  \
# Patient ID       ...
# 44477f75e8169d2  ...              NaN                       NaN           NaN
# 126e9dd13932f68  ...     not_detected              not_detected  not_detected
# a46b4402a0e5696  ...              NaN                       NaN           NaN
# f7d619a94f97c45  ...              NaN                       NaN           NaN
# d9e41465789c2b5  ...     not_detected              not_detected  not_detected
#
#                  Parainfluenza 4  Coronavirus229E  CoronavirusOC43  \
# Patient ID
# 44477f75e8169d2              NaN              NaN              NaN
# 126e9dd13932f68     not_detected     not_detected     not_detected
# a46b4402a0e5696              NaN              NaN              NaN
# f7d619a94f97c45              NaN              NaN              NaN
# d9e41465789c2b5     not_detected     not_detected     not_detected
#
#                 Inf A H1N1 2009 Bordetella pertussis Metapneumovirus  \
# Patient ID
# 44477f75e8169d2             NaN                  NaN             NaN
# 126e9dd13932f68    not_detected         not_detected    not_detected
# a46b4402a0e5696             NaN                  NaN             NaN
# f7d619a94f97c45             NaN                  NaN             NaN
# d9e41465789c2b5    not_detected         not_detected    not_detected
#
#                 Parainfluenza 2
# Patient ID
# 44477f75e8169d2             NaN
# 126e9dd13932f68    not_detected
# a46b4402a0e5696             NaN
# f7d619a94f97c45             NaN
# d9e41465789c2b5    not_detected
#
# [5 rows x 33 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
trainset, testset = train_test_split(df, test_size=0.2, random_state=0)

# %%
trainset['SARS-Cov-2 exam result'].value_counts()
# Out:
# negative    4068
# positive     447
# Name: SARS-Cov-2 exam result, dtype: int64

# %%
testset['SARS-Cov-2 exam result'].value_counts()
# Out:
# negative    1018
# positive     111
# Name: SARS-Cov-2 exam result, dtype: int64

# %%
def encodage(df):
    code = {'negative':0,
            'positive':1,
            'not_detected':0,
            'detected':1}
    for col in df.select_dtypes('object').columns:
        df.loc[:,col] = df[col].map(code)
    return df

# %%
def imputation(df):
    #df['is na'] = (df['Parainfluenza 3'].isna()) | (df['Leukocytes'].isna())
    #df = df.fillna(-999)
    df = df.dropna(axis=0)
    return df

# %%
def feature_engineering(df):
    df['est malade'] = df[viral_columns].sum(axis=1) >= 1
    df = df.drop(viral_columns, axis=1)
    return df

# %%
def preprocessing(df):
    df = encodage(df)
    df = feature_engineering(df)
    df = imputation(df)
    
    X = df.drop('SARS-Cov-2 exam result', axis=1)
    y = df['SARS-Cov-2 exam result']
    
    print(y.value_counts())
    
    return X , y

# %%
X_train, y_train = preprocessing(trainset)
# Out:
# 0    422
# 1     65
# Name: SARS-Cov-2 exam result, dtype: int64

# %%
X_test, y_test = preprocessing(testset) # positive = 10% de negative
# Out:
# 0    95
# 1    16
# Name: SARS-Cov-2 exam result, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import PolynomialFeatures
from sklearn.decomposition import PCA   
# modellisation

# %%
model_1 = RandomForestClassifier(random_state=0)

# %%
model_2 = make_pipeline(PolynomialFeatures(2), SelectKBest(f_classif, k=10),
                      RandomForestClassifier(random_state=0)) #test de anova selectionner les 10 meilleure 
                                                              #variable pour notre model

# %%
from sklearn.metrics import f1_score, confusion_matrix, classification_report
from sklearn.model_selection import learning_curve
# evaluation

# %%
def evaluation(model):
    model.fit(X_train, y_train)
    ypred = model.predict(X_test)
    
    print(confusion_matrix(y_test, ypred))
    print(classification_report(y_test,ypred))
    
    N, train_score, val_score = learning_curve(model, X_train , y_train, cv=4, scoring='f1', train_sizes=np.linspace(0.1,1,10))
    
    plt.figure(figsize=(12,8))
    plt.plot(N, train_score.mean(axis=1), label='train score')
    plt.plot(N, val_score.mean(axis=1), label='validation score')
    plt.legend()

# %%
evaluation(model_1)
# Out:
# [[92  3]
#  [13  3]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92        95
#            1       0.50      0.19      0.27        16
#
#     accuracy                           0.86       111
#    macro avg       0.69      0.58      0.60       111
# weighted avg       0.82      0.86      0.83       111

# %%
pd.DataFrame(model_1.feature_importances_, index=X_train.columns).plot.bar(figsize=(12, 8))
# Out:
# <AxesSubplot:>

# %%
evaluation(model_2)
# Out:
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# [[91  4]
#  [11  5]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.92        95
#            1       0.56      0.31      0.40        16
#
#     accuracy                           0.86       111
#    macro avg       0.72      0.64      0.66       111
# weighted avg       0.84      0.86      0.85       111
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\jawhe\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
